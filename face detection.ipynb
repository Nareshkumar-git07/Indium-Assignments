# %%
! pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=plt.imread("Desktop\IMG-20170629-WA0009.jpg")

# %%
img.shape
# Out:
# (1000, 563, 3)

# %%
plt.imshow(img)
